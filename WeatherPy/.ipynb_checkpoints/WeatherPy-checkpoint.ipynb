# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

#Test both list to see the information is opened

#lat_lngs
#cities
# Out:
# 589

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#finding in the 

#locating the information within the API required of each city 

#City / weather_json['name']
#Cloudiness / weather_json['clouds']['all']
# Country / weather_json['sys']['country']   
# Date   / weather_json['dt']
# Humidity   / weather_json['main']['humidity']
# Lat   / weather_json['coord']['lat']
# Lng  /  weather_json['coord']['lon']  
# Max Temp    / weather_json['main']['temp_max']    
# Wind Speed  /  weather_json['wind']['speed']

# %%
#Create list to hold the information

city_name = []
cloudines = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []
not_located = []
loop = 1

units='imperial'
base_url= 'http://api.openweathermap.org/data/2.5/weather?'

# %%
#
print('Beginning Data Retrieval')
print('-----------------------------')

#creating the loop to generate the various requests

for x in cities:
    
    query_url = f"{base_url}appid={weather_api_key}&units={units}&q="
    weather_response = requests.get(query_url + x)
    weather_json=weather_response.json()

#requesting the information from the API from each city.

    try:
        city_name.append(weather_json['name'])
        cloudines.append(weather_json['clouds']['all'])
        country.append(weather_json['sys']['country'])
        date.append(weather_json['dt'])
        humidity.append(weather_json['main']['humidity'])
        lat.append(weather_json['coord']['lat'])
        lon.append(weather_json['coord']['lat'])
        max_temp.append(weather_json['main']['temp_max'])
        wind_speed.append(weather_json['wind']['speed'])
        print(f'processing record {loop} | {x}')

# use exception to jump the missing cities and keep the code alive.

    except KeyError:
        not_located.append(x)
        print(f'City ({x}) city not found. Skipping...')
        loop=loop-1
    loop+=1
  
print('-----------------------------') 
print('Data Retrieval Complete')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# processing record 1 | rikitea
# processing record 2 | nguruka
# City (nizhneyansk) city not found. Skipping...
# processing record 3 | lavrentiya
# City (rawannawi) city not found. Skipping...
# processing record 4 | georgetown
# processing record 5 | kholtoson
# processing record 6 | euclides da cunha
# processing record 7 | hasaki
# processing record 8 | punta arenas
# processing record 9 | lagoa vermelha
# City (mys shmidta) city not found. Skipping...
# processing record 10 | deputatskiy
# processing record 11 | qaanaaq
# processing record 12 | ahuimanu
# City (barentsburg) city not found. Skipping...
# processing record 13 | cabo san lucas
# City (saleaula) city not found. Skipping...
# processing record 14 | ushuaia
# City (taolanaro) city not found. Skipping...
# processing record 15 | kapaa
# processing record 16 | albany
# processing record 17 | bilibino
# processing record 18 | castro
# processing record 19 | pevek
# processing record 20 | mutis
# processing record 21 | barrow
# processing record 22 | mar del plata
# City (karaul) city not found. Skipping...
# processing record 23 | chokurdakh
# processing record 24 | pisco
# processing record 25 | zaria
# processing record 26 | tefe
# processing record 27 | sulangan
# processing record 28 | jamestown
# processing record 29 | muros
# processing record 30 | mataura
# processing record 31 | port elizabeth
# processing record 32 | priargunsk
# processing record 33 | longyearbyen
# processing record 34 | along
# processing record 35 | chumikan
# processing record 36 | saint-philippe
# processing record 37 | fortuna
# processing record 38 | port alfred
# processing record 39 | atuona
# processing record 40 | tiksi
# processing record 41 | mwanza
# processing record 42 | namie
# processing record 43 | ancud
# processing record 44 | hilo
# processing record 45 | nkowakowa
# processing record 46 | quatre cocos
# processing record 47 | banjar
# processing record 48 | arraial do cabo
# processing record 49 | carnarvon
# processing record 50 | college
# processing record 51 | lebu
# processing record 52 | saskylakh
# processing record 53 | baracoa
# City (amderma) city not found. Skipping...
# processing record 54 | necochea
# processing record 55 | mount gambier
# processing record 56 | busselton
# processing record 57 | hobart
# processing record 58 | heihe
# processing record 59 | camacha
# processing record 60 | narsaq
# processing record 61 | palauig
# processing record 62 | hermanus
# processing record 63 | cockburn town
# processing record 64 | bentiu
# processing record 65 | botwood
# processing record 66 | charters towers
# processing record 67 | cravo norte
# processing record 68 | high rock
# processing record 69 | baykit
# processing record 70 | aksarka
# processing record 71 | nikolskoye
# processing record 72 | batagay-alyta
# processing record 73 | ribeira grande
# processing record 74 | martapura
# City (belushya guba) city not found. Skipping...
# processing record 75 | atlantic city
# processing record 76 | arlit
# processing record 77 | new norfolk
# processing record 78 | batetskiy
# City (khonuu) city not found. Skipping...
# processing record 79 | anjozorobe
# processing record 80 | rosario
# processing record 81 | gat
# processing record 82 | khasan
# processing record 83 | erzin
# processing record 84 | faanui
# processing record 85 | merauke
# processing record 86 | hamilton
# processing record 87 | souillac
# processing record 88 | ravanusa
# processing record 89 | tashtyp
# processing record 90 | haines junction
# processing record 91 | torbay
# processing record 92 | mwinilunga
# processing record 93 | mahebourg
# processing record 94 | nanortalik
# processing record 95 | bluff
# processing record 96 | ojinaga
# processing record 97 | yumen
# processing record 98 | bowmore
# processing record 99 | ngunguru
# processing record 100 | bandarbeyla
# processing record 101 | sharan
# processing record 102 | lazeshchyna
# processing record 103 | alta floresta
# processing record 104 | khatanga
# processing record 105 | bethel
# City (grand river south east) city not found. Skipping...
# processing record 106 | udachnyy
# processing record 107 | avarua
# processing record 108 | mayya
# processing record 109 | puerto ayora
# processing record 110 | hirado
# processing record 111 | norman wells
# processing record 112 | saint george
# processing record 113 | grand bend
# processing record 114 | sand springs
# processing record 115 | hithadhoo
# processing record 116 | kodiak
# processing record 117 | severo-kurilsk
# processing record 118 | butaritari
# processing record 119 | gidam
# processing record 120 | kabo
# City (palabuhanratu) city not found. Skipping...
# processing record 121 | manono
# processing record 122 | laguna
# processing record 123 | cape town
# City (tumannyy) city not found. Skipping...
# processing record 124 | zabid
# processing record 125 | coruripe
# processing record 126 | provideniya
# City (eskasem) city not found. Skipping...
# processing record 127 | leeton
# processing record 128 | salalah
# processing record 129 | yantal
# processing record 130 | lata
# processing record 131 | ostrovnoy
# processing record 132 | comodoro rivadavia
# processing record 133 | trelew
# processing record 134 | dehloran
# processing record 135 | clyde river
# processing record 136 | huilong
# processing record 137 | dikson
# processing record 138 | tasiilaq
# processing record 139 | almaznyy
# processing record 140 | kholodnyy
# City (bandar-e torkaman) city not found. Skipping...
# processing record 141 | asau
# City (illoqqortoormiut) city not found. Skipping...
# processing record 142 | saint-augustin
# processing record 143 | shitanjing
# processing record 144 | salina
# processing record 145 | kudahuvadhoo
# processing record 146 | codrington
# processing record 147 | zirgan
# processing record 148 | vardo
# processing record 149 | saint-georges
# processing record 150 | iqaluit
# processing record 151 | adrar
# processing record 152 | lalin
# processing record 153 | duki
# processing record 154 | caravelas
# processing record 155 | benjamin constant
# processing record 156 | bathsheba
# processing record 157 | auki
# processing record 158 | te anau
# processing record 159 | bredasdorp
# processing record 160 | olafsvik
# processing record 161 | fort morgan
# processing record 162 | hobyo
# processing record 163 | airai
# processing record 164 | redmond
# processing record 165 | biak
# processing record 166 | fort nelson
# processing record 167 | esperance
# processing record 168 | cortes
# processing record 169 | namibe
# City (tidore) city not found. Skipping...
# processing record 170 | shaunavon
# processing record 171 | san policarpo
# processing record 172 | kaeo
# processing record 173 | chuy
# processing record 174 | lagoa
# processing record 175 | broome
# processing record 176 | krasnaya gora
# City (higuey) city not found. Skipping...
# processing record 177 | badarpur
# processing record 178 | san cristobal
# processing record 179 | thompson
# processing record 180 | san patricio
# processing record 181 | batagay
# processing record 182 | samarai
# processing record 183 | veraval
# processing record 184 | smithers
# processing record 185 | tuktoyaktuk
# processing record 186 | paita
# processing record 187 | shreveport
# processing record 188 | ponta do sol
# processing record 189 | vanavara
# processing record 190 | synya
# processing record 191 | nantucket
# processing record 192 | kita
# processing record 193 | dingle
# City (samusu) city not found. Skipping...
# processing record 194 | mahon
# processing record 195 | connersville
# processing record 196 | cedar city
# processing record 197 | miri
# processing record 198 | villazon
# processing record 199 | grindavik
# processing record 200 | honiara
# processing record 201 | kavaratti
# processing record 202 | nazret
# processing record 203 | nadym
# City (marcona) city not found. Skipping...
# processing record 204 | magadan
# processing record 205 | vostok
# processing record 206 | camabatela
# processing record 207 | jalu
# processing record 208 | zapadnaya dvina
# processing record 209 | boa vista
# processing record 210 | tyler
# processing record 211 | tabou
# processing record 212 | vaini
# processing record 213 | milanowek
# processing record 214 | mae sai
# processing record 215 | arona
# processing record 216 | cairns
# processing record 217 | liuzhou
# processing record 218 | port hardy
# processing record 219 | slave lake
# processing record 220 | ngaoundere
# processing record 221 | aklavik
# processing record 222 | kainantu
# processing record 223 | marawi
# processing record 224 | khorinsk
# processing record 225 | ereymentau
# processing record 226 | koster
# processing record 227 | skegness
# processing record 228 | alice springs
# City (kamenskoye) city not found. Skipping...
# processing record 229 | murmino
# processing record 230 | san vicente
# processing record 231 | fairlie
# processing record 232 | geraldton
# processing record 233 | katsuura
# processing record 234 | cidreira
# processing record 235 | neustadt
# processing record 236 | tyukhtet
# processing record 237 | prince rupert
# processing record 238 | saldanha
# processing record 239 | beidao
# processing record 240 | kruisfontein
# processing record 241 | dahegam
# City (vaitupu) city not found. Skipping...
# processing record 242 | svetlyy
# processing record 243 | east london
# processing record 244 | moultrie
# processing record 245 | mareeba
# processing record 246 | buchanan
# processing record 247 | luzhou
# processing record 248 | mayor pablo lagerenza
# processing record 249 | champerico
# processing record 250 | kungurtug
# City (attawapiskat) city not found. Skipping...
# processing record 251 | teya
# City (bolungarvik) city not found. Skipping...
# processing record 252 | lodwar
# processing record 253 | port macquarie
# processing record 254 | kirakira
# processing record 255 | zhigansk
# processing record 256 | vao
# processing record 257 | opunake
# City (kuche) city not found. Skipping...
# processing record 258 | birjand
# processing record 259 | puno
# processing record 260 | bambous virieux
# processing record 261 | kemerovo
# processing record 262 | forestville
# processing record 263 | persianovskiy
# processing record 264 | puerto escondido
# processing record 265 | fairbanks
# processing record 266 | wilmington
# processing record 267 | victoria
# processing record 268 | aldergrove
# processing record 269 | killybegs
# processing record 270 | varna
# City (sentyabrskiy) city not found. Skipping...
# City (baie du tombeau) city not found. Skipping...
# processing record 271 | mangai
# processing record 272 | aksu
# processing record 273 | cayenne
# processing record 274 | fredericksburg
# processing record 275 | berlevag
# processing record 276 | tamworth
# processing record 277 | gualeguay
# processing record 278 | solnechnyy
# processing record 279 | vila velha
# processing record 280 | pingyin
# processing record 281 | saint john
# processing record 282 | sur
# processing record 283 | luderitz
# processing record 284 | jijiga
# processing record 285 | talnakh
# City (bargal) city not found. Skipping...
# processing record 286 | ust-nera
# processing record 287 | kaitangata
# processing record 288 | keetmanshoop
# processing record 289 | choix
# processing record 290 | sioux lookout
# processing record 291 | komsomolskiy
# processing record 292 | port lincoln
# City (manzil jamil) city not found. Skipping...
# processing record 293 | miramar
# processing record 294 | lasa
# processing record 295 | touros
# City (tsihombe) city not found. Skipping...
# processing record 296 | belmonte
# processing record 297 | bay roberts
# processing record 298 | sao filipe
# processing record 299 | leningradskiy
# processing record 300 | pangnirtung
# processing record 301 | hearst
# processing record 302 | abadiania
# processing record 303 | barcelos
# processing record 304 | conceicao do araguaia
# processing record 305 | inhambane
# processing record 306 | cruzilia
# processing record 307 | riyadh
# processing record 308 | kahuta
# processing record 309 | kupang
# processing record 310 | mezen
# processing record 311 | trinidad
# processing record 312 | tessalit
# processing record 313 | bud
# processing record 314 | egvekinot
# processing record 315 | tura
# processing record 316 | zyryanka
# processing record 317 | lanzhou
# processing record 318 | siniscola
# processing record 319 | saint-lo
# processing record 320 | shibetsu
# processing record 321 | avera
# processing record 322 | kuzovatovo
# processing record 323 | maracaju
# processing record 324 | hofn
# processing record 325 | heimberg
# processing record 326 | naze
# processing record 327 | presidente medici
# processing record 328 | bengkulu
# processing record 329 | san francisco
# processing record 330 | upernavik
# processing record 331 | la argentina
# processing record 332 | alugan
# processing record 333 | yellowknife
# processing record 334 | omsukchan
# processing record 335 | timon
# processing record 336 | gizo
# processing record 337 | amberley
# processing record 338 | ahipara
# processing record 339 | toktogul
# processing record 340 | dunmore town
# processing record 341 | ambilobe
# processing record 342 | varadero
# processing record 343 | ares
# processing record 344 | luocheng
# processing record 345 | chingola
# processing record 346 | beringovskiy
# processing record 347 | jimeta
# processing record 348 | lodja
# processing record 349 | normandin
# processing record 350 | vilnius
# processing record 351 | constantine
# processing record 352 | susanville
# processing record 353 | husavik
# processing record 354 | kropotkin
# processing record 355 | aripuana
# processing record 356 | palafrugell
# processing record 357 | rundu
# processing record 358 | arkhara
# processing record 359 | roald
# processing record 360 | linqiong
# processing record 361 | le port
# processing record 362 | masterton
# processing record 363 | mehamn
# processing record 364 | sagua la grande
# processing record 365 | isangel
# processing record 366 | tonstad
# processing record 367 | sambava
# processing record 368 | hovd
# processing record 369 | semporna
# processing record 370 | springdale
# processing record 371 | vestmannaeyjar
# City (westpunt) city not found. Skipping...
# processing record 372 | high level
# processing record 373 | mishan
# processing record 374 | itainopolis
# processing record 375 | cherskiy
# processing record 376 | gniezno
# processing record 377 | samana
# processing record 378 | maltahohe
# processing record 379 | ola
# processing record 380 | constitucion
# processing record 381 | manokwari
# processing record 382 | iralaya
# processing record 383 | wanaka
# processing record 384 | batemans bay
# processing record 385 | rayevskaya
# processing record 386 | grand-santi
# processing record 387 | meulaboh
# processing record 388 | namatanai
# processing record 389 | sao felix do xingu
# processing record 390 | arica
# City (canitas) city not found. Skipping...
# processing record 391 | savinskiy
# processing record 392 | balkanabat
# processing record 393 | tuatapere
# processing record 394 | verkhoyansk
# processing record 395 | marsa matruh
# processing record 396 | portland
# processing record 397 | biu
# processing record 398 | bemidji
# processing record 399 | severnoye
# processing record 400 | kitimat
# processing record 401 | atar
# processing record 402 | fukue
# processing record 403 | vanino
# processing record 404 | saint anthony
# processing record 405 | port hedland
# processing record 406 | traralgon
# processing record 407 | ambon
# processing record 408 | kasongo
# processing record 409 | lilongwe
# processing record 410 | skibbereen
# processing record 411 | bayan
# processing record 412 | buala
# processing record 413 | wanning
# processing record 414 | grand gaube
# processing record 415 | kiama
# City (wulanhaote) city not found. Skipping...
# processing record 416 | sinnamary
# processing record 417 | lasem
# processing record 418 | kstovo
# processing record 419 | ouango
# processing record 420 | poum
# processing record 421 | magaria
# processing record 422 | lere
# processing record 423 | najran
# processing record 424 | umm kaddadah
# processing record 425 | hornepayne
# processing record 426 | port angeles
# processing record 427 | sotouboua
# processing record 428 | uglegorskiy
# processing record 429 | xuddur
# processing record 430 | alofi
# processing record 431 | brewster
# processing record 432 | ipora
# processing record 433 | sungairaya
# City (fort saint john) city not found. Skipping...
# processing record 434 | bonthe
# processing record 435 | kalat
# processing record 436 | yar-sale
# processing record 437 | oranjemund
# processing record 438 | santa cruz
# processing record 439 | klaksvik
# processing record 440 | ilulissat
# processing record 441 | nelson bay
# processing record 442 | havre-saint-pierre
# City (himora) city not found. Skipping...
# processing record 443 | antofagasta
# processing record 444 | vagay
# City (calobre) city not found. Skipping...
# City (garm) city not found. Skipping...
# processing record 445 | batsfjord
# processing record 446 | balaipungut
# processing record 447 | bonavista
# processing record 448 | mingguang
# processing record 449 | rolla
# processing record 450 | nybro
# City (talawdi) city not found. Skipping...
# processing record 451 | miami
# processing record 452 | mayo
# processing record 453 | champasak
# processing record 454 | okhotsk
# processing record 455 | black forest
# City (louisbourg) city not found. Skipping...
# processing record 456 | gamba
# processing record 457 | canico
# processing record 458 | margate
# processing record 459 | santana
# processing record 460 | lisakovsk
# processing record 461 | kavieng
# processing record 462 | rapid valley
# processing record 463 | umm lajj
# processing record 464 | liepaja
# processing record 465 | sao jose da coroa grande
# processing record 466 | at-bashi
# processing record 467 | savannah bight
# processing record 468 | jeremoabo
# processing record 469 | guerrero negro
# processing record 470 | nalut
# processing record 471 | soyo
# processing record 472 | letka
# processing record 473 | kamaishi
# processing record 474 | itaueira
# processing record 475 | labuan
# processing record 476 | anadyr
# processing record 477 | labrea
# processing record 478 | keti bandar
# processing record 479 | kanniyakumari
# processing record 480 | grants
# processing record 481 | concarneau
# processing record 482 | tahta
# processing record 483 | monster
# processing record 484 | puerto madryn
# processing record 485 | dunedin
# processing record 486 | rosarito
# processing record 487 | salta
# processing record 488 | tezu
# processing record 489 | teknaf
# City (tingrela) city not found. Skipping...
# processing record 490 | cherepovets
# processing record 491 | sovetskaya gavan
# processing record 492 | sijunjung
# processing record 493 | stonewall
# processing record 494 | vikulovo
# processing record 495 | taltal
# processing record 496 | balbriggan
# processing record 497 | lompoc
# processing record 498 | iquique
# processing record 499 | crotone
# processing record 500 | mapiripan
# processing record 501 | tucurui
# processing record 502 | nong phai
# processing record 503 | ibra
# processing record 504 | hare bay
# processing record 505 | takoradi
# processing record 506 | kieta
# processing record 507 | cam ranh
# processing record 508 | rawson
# processing record 509 | chissamba
# City (muzquiz) city not found. Skipping...
# processing record 510 | solnice
# processing record 511 | barahona
# processing record 512 | manicore
# processing record 513 | srednekolymsk
# processing record 514 | nome
# processing record 515 | kendari
# processing record 516 | kahului
# City (artyk) city not found. Skipping...
# processing record 517 | atasu
# processing record 518 | padang
# processing record 519 | lucea
# processing record 520 | hervey bay
# processing record 521 | kendal
# processing record 522 | coari
# processing record 523 | astoria
# processing record 524 | sisimiut
# processing record 525 | waipawa
# processing record 526 | dryden
# processing record 527 | pontes e lacerda
# processing record 528 | tucdao
# processing record 529 | wajima
# processing record 530 | hami
# processing record 531 | nushki
# processing record 532 | show low
# processing record 533 | mumford
# processing record 534 | luau
# processing record 535 | sitka
# processing record 536 | chkalovskoye
# processing record 537 | saurimo
# processing record 538 | matay
# processing record 539 | ucluelet
# processing record 540 | ranot
# processing record 541 | nebbi
# processing record 542 | tari
# processing record 543 | nautla
# processing record 544 | adre
# processing record 545 | narrabri
# processing record 546 | sorong
# City (solsvik) city not found. Skipping...
# processing record 547 | whitehorse
# processing record 548 | orcopampa
# processing record 549 | xiropotamos
# processing record 550 | lesu
# processing record 551 | anchorage
# processing record 552 | tabuk
# processing record 553 | winnemucca
# processing record 554 | pinega
# processing record 555 | moyale
# processing record 556 | griffith
# processing record 557 | ponnani
# City (anar darreh) city not found. Skipping...
# processing record 558 | ystad
# processing record 559 | whittlesea
# processing record 560 | dubai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Create list to

# %%
print(f'{len(not_located)}/{len(cities)} cities were not found')

not_located=set(not_located)
cities=set(cities)
updated_cities = list(cities-not_located)
# Out:
# 44/589 cities were not found

# %%
#format the column of dates of the df
dates=[]
for city in date:
    date_test=city
    date_conversion=time.gmtime(date_test)
    date_format=time.strftime('%m/%d/%Y',date_conversion)
    dates.append(date_format)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create data frame with the information requested from API
weather_df=pd.DataFrame({"City": city_name,
                        'Cloudiness': cloudines,
                        'Country': country,
                        'Date': date,
                        'Humidity (%)': humidity,
                        'Latitude': lat,
                        'Longitude': lon,
                        'Max Temperature': max_temp,
                        'Wind Speed (MPH)': wind_speed})
#weather_df.dtypes

#display the data frame weather created 
weather_df.count()
# Out:
# City                560
# Cloudiness          560
# Country             560
# Date                560
# Humidity (%)        560
# Latitude            560
# Longitude           560
# Max Temperature     560
# Wind Speed (MPH)    560
# dtype: int64

# %%
#Exporting DF Cities as a CSV File 

cities_df=pd.DataFrame({"City": city_name,
                        'Cloudiness': cloudines,
                        'Country': country,
                        'Date': date,
                        'Humidity (%)': humidity,
                        'Latitude': lat,
                        'Longitude': lon,
                        'Max Temperature': max_temp,
                        'Wind Speed (MPH)': wind_speed})

cities_df.to_csv("Output_Data/Cities.csv",index=False)

# %%
cities_df.head(5)
# Out:
#           City  Cloudiness Country        Date  Humidity (%)  Latitude  \
# 0      Rikitea          24      PF  1584150051            74    -23.12
# 1      Nguruka         100      TZ  1584150051            97     -5.11
# 2   Lavrentiya         100      RU  1584150052            95     65.58
# 3  George Town          20      MY  1584150052            83      5.41
# 4    Kholtoson           0      RU  1584150052            61     50.30
#
#    Longitude  Max Temperature  Wind Speed (MPH)
# 0     -23.12            77.11             12.35
# 1      -5.11            63.72              2.42
# 2      65.58            29.97             20.45
# 3       5.41            86.00              3.36
# 4      50.30            26.24              3.02

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#plotting lat vs temp 

#Creating the variables to use from the dataframe to make the scatter plot

x_axis_latitude = weather_df.loc[:,'Latitude']
y_axis_temp = weather_df.loc[:,'Max Temperature']

#creating the scatter plot
plt.scatter(x_axis_latitude,y_axis_temp, edgecolor='green', alpha=.5)

#formating the graph
plt.title(f'City Latitude Vs Max Temperature {dates[0]}')
plt.ylabel('Max Temp. (f)')
plt.xlabel('Latitude')
plt.grid(alpha=0.2)
plt.ylim(min(y_axis_temp)-20,max(y_axis_temp)+20)

#printing out the final graph

plt.savefig('Output_Data/latitude_MaxTemp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#establishing variables from the df to create the scatter plot
x_axis_latitude = weather_df.loc[:,'Latitude']
y_axis_humidity = weather_df.loc[:,'Humidity (%)']

#creating the scatter plot
plt.scatter(x_axis_latitude,y_axis_humidity , edgecolor='magenta', alpha=.5)

#formating the graph
plt.title(f'City Latitude Vs Humidity %  {dates[0]}')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(alpha=0.2)
plt.ylim(min(y_axis_humidity)-10,max(y_axis_humidity)+10)

#printing out the final graph

plt.savefig('Output_Data/latitude_humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#establishing variables from the df to create the scatter plot
x_axis_latitude = weather_df.loc[:,'Latitude']
y_axis_cloudiness = weather_df.loc[:,'Cloudiness']

#creating the scatter plot
plt.scatter(x_axis_latitude,y_axis_cloudiness , edgecolor='blue', alpha=.5)

#formating the graph
plt.title(f'City Latitude Vs Cloudiness  {dates[0]}')
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.grid(alpha=0.2)
plt.ylim(min(y_axis_cloudiness)-10,max(y_axis_cloudiness)+10)

#printing out the final graph

plt.savefig('Output_Data/latitude_cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#establishing variables from the df to create the scatter plot
x_axis_latitude = weather_df.loc[:,'Latitude']
y_axis_wind_speed = weather_df.loc[:,'Wind Speed (MPH)']

#creating the scatter plot
plt.scatter(x_axis_latitude,y_axis_wind_speed , edgecolor='gray', alpha=.5)

#formating the graph
plt.title(f'City Latitude Vs Wind Speed {dates[0]}')
plt.ylabel('Wind Speed (MPH)')
plt.xlabel('Latitude')
plt.grid(alpha=0.2)
plt.ylim(min(y_axis_wind_speed)-5,max(y_axis_wind_speed)+5)

#printing out the final graph

plt.savefig('Output_Data/latitude_winspeed.png')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# #Create function to plot each graph with line of best fit:
# def plot_graph(x,y):
#     plt.scatter(x,y)
#     plt.xlim(min(x)-3,max(x)+2)
#     plt.ylim(min(y)-4,max(y)+4)
#     #Correlation
#     _slope, _int, _r, _p, _std_err = st.linregress(x,y)
#     best_fit = _slope * x + _int
#     plt.plot(x,best_fit,"r--", linewidth=.5)
#     line_eq = "y = " + str(round(_slope,2)) + "x + " + str(round(_int,2))
#     plt.annotate(line_eq,(min(x)+10,min(y)+20),fontsize=12,color="red")
#     #pearon correlation statement
#     pearson_r=st.pearsonr(x,y)[0]
#     if abs(pearson_r)>0.7:
#         print(f'The r value is {round(pearson_r,2)}, there is strong correlation between the city latitude and weather')
#     elif abs(pearson_r)>0.5:
#         print(f'The r value is {round(pearson_r,2)}, there is a moderate correlation between the city latitude and weather')
#     elif abs(pearson_r)>0.3:
#         print(f'The r value is {round(pearson_r,2)}, there is a weak correlation between the city latitude and weather')
#     else:
#         print(f'The r value is {round(pearson_r,2)}, there is no correlation between the city latitude and weather')

# %%
# Create Northern and Southern Hemisphere DataFrames

north_hemisphere_df = weather_df.loc[weather_df['Latitude']>=0]
south_hemisphere_df = weather_df.loc[weather_df['Latitude']<0]

#Testing the data frames created
#north_hemisphere_df
south_hemisphere_df
# Out:
#                   City  Cloudiness Country        Date  Humidity (%)  \
# 0              Rikitea          24      PF  1584150051            74
# 1              Nguruka         100      TZ  1584150051            97
# 5    Euclides da Cunha          90      BR  1584150000            81
# 7         Punta Arenas          57      CL  1584150052            61
# 8       Lagoa Vermelha          37      BR  1584150053            58
# ..                 ...         ...     ...         ...           ...
# 536            Saurimo         100      AO  1584150122            98
# 544           Narrabri           0      AU  1584150123            44
# 545             Sorong         100      ID  1584150123            85
# 547          Orcopampa         100      PE  1584150123            96
# 558         Whittlesea          10      ZA  1584150125            77
#
#      Latitude  Longitude  Max Temperature  Wind Speed (MPH)
# 0      -23.12     -23.12            77.11             12.35
# 1       -5.11      -5.11            63.72              2.42
# 5      -10.51     -10.51            71.47              6.76
# 7      -53.15     -53.15            50.00             12.75
# 8      -28.21     -28.21            71.17              9.42
# ..        ...        ...              ...               ...
# 536     -9.66      -9.66            64.92              2.19
# 544    -30.32     -30.32            78.80              8.05
# 545     -0.88      -0.88            82.54              4.07
# 547    -15.27     -15.27            37.85              5.70
# 558    -32.18     -32.18            57.36              3.11
#
# [174 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_temp = north_hemisphere_df.loc[:,'Max Temperature']
north_latitude = north_hemisphere_df.loc[:,'Latitude']

y = north_temp 
x = north_latitude

#calculating the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x,y)
print(f"The correlation factor is {round(rvalue, 2)}")

# #format
plt.title(f"Northern Hemisphere - Max Temp vs. Latitude Linear Regression {dates[0]}")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
regress = x * slope + intercept

line_eq = print(f"y = {round(slope, 2)}x + {round(intercept, 2)}")
plt.scatter(x, y)
plt.plot(x, regress, "r--")
plt.show()

plt.savefig("output_data/maxtemp_lat_LR.png")
# Out:
# The correlation factor is -0.89
# y = -1.2x + 92.88

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_latitude = south_hemisphere_df.loc[:,'Latitude']
south_temp = south_hemisphere_df.loc[:,'Max Temperature']

x = south_latitude
y = south_temp


#calculating the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x,y)
print(f"The correlation factor is {round(rvalue, 2)}")

# #format
plt.title(f"Southern Hemisphere - Max Temp vs. Latitude Linear Regression {dates[0]}")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
regress = x * slope + intercept

line_eq = print(f"y = {round(slope, 2)}x + {round(intercept, 2)}")
plt.scatter(x, y)
plt.plot(x, regress, "r--")
plt.show()

plt.savefig("output_data/maxtemp_slat_LR.png")
# Out:
# The correlation factor is 0.53
# y = 0.39x + 80.75

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_humidity = north_hemisphere_df.loc[:,'Humidity (%)']
north_latitude = north_hemisphere_df.loc[:,'Latitude']

y = north_humidity 
x = north_latitude

#calculating the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x,y)
print(f"The correlation factor is {round(rvalue, 2)}")

# #format
plt.title(f"Northern Hemisphere - Humidty vs. Latitude Linear Regression {dates[0]}")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
regress = x * slope + intercept

line_eq = print(f"y = {round(slope, 2)}x + {round(intercept, 2)}")
plt.scatter(x, y)
plt.plot(x, regress, "r--")
plt.show()

plt.savefig("output_data/humidity_Nlat_LR.png")
# Out:
# The correlation factor is 0.26
# y = 0.3x + 57.18

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_latitude = south_hemisphere_df.loc[:,'Latitude']
south_humidity = south_hemisphere_df.loc[:,'Humidity (%)']

x = south_latitude
y = south_humidity


#calculating the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x,y)
print(f"The correlation factor is {round(rvalue, 2)}")

# #format
plt.title(f"Southern Hemisphere - Humidity vs. Latitude Linear Regression {dates[0]}")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
regress = x * slope + intercept

line_eq = print(f"y = {round(slope, 2)}x + {round(intercept, 2)}")
plt.scatter(x, y)
plt.plot(x, regress, "r--")
plt.show()

plt.savefig("output_data/humidity_slat_LR.png")
# Out:
# The correlation factor is 0.37
# y = 0.49x + 86.47

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_latitude = north_hemisphere_df.loc[:,'Latitude']
north_cloudiness = north_hemisphere_df.loc[:,'Cloudiness']

x = north_latitude
y = north_humidity 


#calculating the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x,y)
print(f"The correlation factor is {round(rvalue, 2)}")

# #format
plt.title(f"Northern Hemisphere - Cloudiness vs. Latitude Linear Regression {dates[0]}")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
regress = x * slope + intercept

line_eq = print(f"y = {round(slope, 2)}x + {round(intercept, 2)}")
plt.scatter(x, y)
plt.plot(x, regress, "r--")
plt.show()

plt.savefig("output_data/cloudiness_Nlat_LR.png")
# Out:
# The correlation factor is 0.26
# y = 0.3x + 57.18

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_latitude = south_hemisphere_df.loc[:,'Latitude']
south_cloudiness = south_hemisphere_df.loc[:,'Cloudiness']

x = south_latitude
y = south_cloudiness


#calculating the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x,y)
print(f"The correlation factor is {round(rvalue, 2)}")

# #format
plt.title(f"Southern Hemisphere - Cloudiness vs. Latitude Linear Regression {dates[0]}")
plt.xlabel("Latitude")
plt.ylabel("Cloudines (%)")
regress = x * slope + intercept

line_eq = print(f"y = {round(slope, 2)}x + {round(intercept, 2)}")
plt.scatter(x, y)
plt.plot(x, regress, "r--")
plt.show()

plt.savefig("output_data/cloudiness_slat_LR.png")
# Out:
# The correlation factor is 0.41
# y = 1.16x + 84.08

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_latitude = north_hemisphere_df.loc[:,'Latitude']
north_windspeed = north_hemisphere_df.loc[:,'Wind Speed (MPH)']

x = north_latitude
y = north_windspeed 


#calculating the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x,y)
print(f"The correlation factor is {round(rvalue, 2)}")

# #format
plt.title(f"Northern Hemisphere - Wind Speed (MPH) vs. Latitude Linear Regression {dates[0]}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
regress = x * slope + intercept

line_eq = print(f"y = {round(slope, 2)}x + {round(intercept, 2)}")
plt.scatter(x, y)
plt.plot(x, regress, "r--")
plt.show()

plt.savefig("output_data/windspeed_Nlat_LR.png")
# Out:
# The correlation factor is 0.24
# y = 0.07x + 6.2

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_latitude = south_hemisphere_df.loc[:,'Latitude']
south_windspeed = south_hemisphere_df.loc[:,'Wind Speed (MPH)']

x = south_latitude
y = south_windspeed


#calculating the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x,y)
print(f"The correlation factor is {round(rvalue, 2)}")

# #format
plt.title(f"Southern Hemisphere - Wind Speed (MPH) vs. Latitude Linear Regression {dates[0]}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
regress = x * slope + intercept

line_eq = print(f"y = {round(slope, 2)}x + {round(intercept, 2)}")
plt.scatter(x, y)
plt.plot(x, regress, "r--")
plt.show()

plt.savefig("output_data/windspeed_slat_LR.png")
# Out:
# The correlation factor is -0.35
# y = -0.15x + 4.56

# %%
# Out:
# The r-squared is: -0.322483077139538
